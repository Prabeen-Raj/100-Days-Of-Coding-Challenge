# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabeen-Raj/100-Days-Of-Coding-Challenge/blob/main/Day%2015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
pip install bs4

# %%
from bs4 import BeautifulSoup
import requests 
import time

# %%
url = 'https://www.google.com/search?&q=bitcoin price in america'
req = requests.get(url)
scrap = BeautifulSoup(req.text, 'html.parser')
print(scrap)
# Out:
# <!DOCTYPE doctype html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>bitcoin price in america - Google Search</title><script nonce="U2C3xvAFWi1zYiW5bJRAiQ==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
bitcoin_price = scrap.find("div", class_="BNeawe iBp4i AP7Wnd").text 
print(bitcoin_price)
# Out:
# 60,946.30 United States Dollar

# %%
i = 0
while i < 10:
  time.sleep(10)
  bitcoin_price = scrap.find("div", class_="BNeawe iBp4i AP7Wnd").text
  print(bitcoin_price)
  i +=1
# Out:
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar

# %%
while True:
  time.sleep(1)
  bitcoin_price = scrap.find("div", class_="BNeawe iBp4i AP7Wnd").text
  print(bitcoin_price)
# Out:
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# 60,946.30 United States Dollar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e55410f9beb9> in <module>()
#       1 while True:
# ----> 2   time.sleep(1)
#       3   bitcoin_price = scrap.find("div", class_="BNeawe iBp4i AP7Wnd").text
#       4   print(bitcoin_price)
#
# ...
